# %% [markdown]
# ## Пазл 1: Петухи и поросята
#
# По тропинке вдоль кустов
# Шли 11 хвостов.
# Сосчитать я также смог,
# Что шагало 30 ног.
# Это вместе шли куда-то
# Петухи и поросята.
# А теперь вопрос таков:
# Сколько было петухов?
# И узнать я был бы рад,
# Сколько было поросят?

# %%
from z3 import *

roosters, pigs = Ints('roosters pigs')
solve(pigs + roosters == 11,        # 11 хвостов
      roosters * 2 + pigs * 4 == 30 # 30 ног
      )

# %% [markdown]
# ## Пазл 2: Три новые задачки
#
# ### 2.1 Криптарифметика: SEND + MORE = MONEY
#
# Каждая буква обозначает свою цифру (одинаковые буквы — одинаковые цифры,
# разные буквы — разные цифры). Числа не начинаются с нуля. Найти, каким
# цифрам соответствуют буквы, чтобы равенство
#
# ```
#   S E N D
# + M O R E
# ---------
# M O N E Y
# ```
#
# выполнялось.

# %%
S, E, N, D, M, O, R, Y = Ints('S E N D M O R Y')
digits = [S, E, N, D, M, O, R, Y]

solve(Distinct(*digits),
      *[And(d >= 0, d <= 9) for d in digits],
      S != 0, M != 0,
      (S*1000 + E*100 + N*10 + D) + (M*1000 + O*100 + R*10 + E)
      == (M*10000 + O*1000 + N*100 + E*10 + Y)
      )

# %% [markdown]
# ### 2.2 Рыцари и лжецы
#
# На острове живут рыцари (всегда говорят правду) и лжецы (всегда лгут).
# Встретились трое: А, Б и В.
#
# - А говорит: "Б и В — оба лжецы."
# - Б говорит: "А — рыцарь."
# - В говорит: "Я и А — разного типа."
#
# Кто из них рыцарь, а кто лжец?

# %%
A, B, C = Bools('A B C')  # True = рыцарь, False = лжец

# Житель говорит правду тогда и только тогда, когда он рыцарь
solve(A == And(Not(B), Not(C)),   # А: "Б и В — оба лжецы"
      B == A,                     # Б: "А — рыцарь"
      C == (C != A)               # В: "Я и А — разного типа"
      )

# %% [markdown]
# ### 2.3 Ферма с курами, коровами и пауками
#
# На ферме держат кур (2 ноги), коров (4 ноги) и пауков (8 ног).
# Всего на ферме 20 голов и 100 ног. Известно, что коров вдвое больше,
# чем пауков. Сколько на ферме кур, коров и пауков?

# %%
chickens, cows, spiders = Ints('chickens cows spiders')

solve(chickens + cows + spiders == 20,               # 20 голов
      chickens*2 + cows*4 + spiders*8 == 100,         # 100 ног
      cows == 2 * spiders,                            # коров вдвое больше пауков
      chickens >= 0, cows >= 0, spiders >= 0
      )

# %% [markdown]
# # Решение пазлов без Z3
#
# ## Пазл 1: Сто долларов и животные
#
# У вас имеется 100 долларов, и вы можете купить 100 животных. Собаки стоят по 15 долларов,
# коты по 1 доллару, мыши по 25 центов. Вы должны купить хотя бы по одному животному каждого
# вида. Найдите решение этого паззла.
#
# **Ответ:** 3 собаки (45$), 41 кот (41$), 56 мышей (14$) — итого 100 животных на 100 долларов.
#
# ---
#
# ## Пазл 2: Восемь ферзей
#
# На шахматной доске надо расставить восемь ферзей так, чтобы никто друг друга не атаковал
# (никакие два ферзя не в одном столбце, строке или диагонали).
#
# **Ответ:** одно из 92 решений — ферзи по столбцам (0-7) стоят на строках:
# 0, 6, 4, 7, 1, 3, 5, 2.
#
# ```
# Q . . . . . . .
# . . . . Q . . .
# . . . . . . . Q
# . . . . . Q . .
# . . Q . . . . .
# . . . . . . Q .
# . Q . . . . . .
# . . . Q . . . .
# ```
#
# ---
#
# ## Пазл 3: Судоку
#
# Есть квадрат 9×9 клеток, и надо заполнить его цифрами от 1 до 9 так, чтобы в каждом
# столбце, в каждой строке и в каждом квадрате 3×3 клетки содержались все цифры от 1 до 9.
#
# **Ответ:** решается алгоритмом backtracking — для каждой пустой клетки перебираются цифры
# 1-9, допустимые по строке/столбцу/квадрату, с откатом при тупике. Оптимизируется constraint
# propagation (сужением множества кандидатов для клеток).
#
# ---
#
# ## Пазл 4: Мотоциклист на светофоре
#
# Мотоциклист стоит на светофоре. Как только загорается зелёный, он стартует с места с
# ускорением 6 м/с² на протяжении 4,1 секунды. Определите расстояние, которое мотоцикл
# преодолеет за это время.
#
# **Ответ:** s = a·t²/2 = 6·4,1²/2 = **50,43 м**.
#
# ---
#
# ## Рефлексия
#
# AI с простыми задачами справляется, но гораздо медленее, чем Z3. Сжигаются токены,
# генерится много текста и рассуждений, которые нужно еще провалидировать. Выглядит так,
# что Z3 идеальный инструмент для решения задач в рамках жестких ограничений в то время
# как AI удобнее использовать в ситуации с большей неопределенностью.
